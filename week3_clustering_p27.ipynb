# %%
import pandas as pd
import numpy as np

# %%
df_name = ['sepal length',
           'sepal width',
           'petal length',
           'petal width',
           'class']
df_origin = pd.read_csv('dataset/iris.data', names=df_name)

df_origin.info()

# %%
# Preprocessing
# Copy dataset
df = df_origin.copy()
